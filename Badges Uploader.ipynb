# %%
import pandas as pd
import os

# Base URL for GitHub repository
BASE_URL = 'https://raw.githubusercontent.com/Sabtha-Rishi/narpavi-product-badges/main/'

# Folder containing images
folder_path = 'Desktop/Website/Narpavi/Brasssss'
# CSV file path
csv_file_path = 'uploader 4.csv'

# Function to generate GitHub URL
def generate_github_url(filename):
    return BASE_URL + filename

# Load CSV file
df = pd.read_csv(csv_file_path)

# %%
df
# Out:
#     Unnamed: 0  S no  Item Code                     Item Name  Height  Length  \
# 0            0     1       7929                  SS ANDAL BIG    25.0    11.0
# 1            1     2      10332                 SS NINDRA LSD    25.0    12.0
# 2            2     3      10332                 SS NINDRA LSD    28.0    20.0
# 3            3     4      10332                 SS NINDRA LSD    26.5    10.5
# 4            4     5      10335          SS UTKARNTHA DANVANT    26.5    13.5
# 5            5     6      10336          SS UTKARNTHA SIVAN P    29.0    16.0
# 6            6     7      10333          SS ARTHA NAREESHWARA    28.5     5.0
# 7            7     9       7930                 SS BALAMBIGAI    20.0    10.0
# 8            8    10      10331               SS BIG KAMAKSHI    20.5    11.5
# 9            9    11      10326            SS KUDAI GANAPATHY    21.0    10.0
# 10          10    12       9127          GDH ANDAL PERIYAZHVA    16.5    16.0
# ...
